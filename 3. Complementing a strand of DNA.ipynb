# %%
def reversecomplement(dna):
    reverse = dna[::-1]
    reverse1 = dna.replace('A', 'T')
    reverse2 = reverse1.replace('G', 'C')
    reverse3 = reverse2.replace('T', 'A')
    reverse4 = reverse4.replace('C', 'G') 
    print reverse4

# %%
reversecomplement('...')
# Out:
# ...

# %%
file1 = '...'

# %%
print file1[::-1]
# Out:
# ...

# %%
reversecomplement(file1)
# Out:
# ...

# %%
print file1.replace('T', 'A')
# Out:
# ...

# %%
reversecomplement(file1)
# Out:
# ...

# %%
file2 = '...'

# %%
reversecomplement(file2)
# Out:
# ...
